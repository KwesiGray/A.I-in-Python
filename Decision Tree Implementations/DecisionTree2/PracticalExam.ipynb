plt.xlabel('x-input feature')
plt.ylabel('y-input feature')
plt.show()

# %%
random_indices=np.random.permutation(100)
random_indices
# Out:
# array([58, 63, 81, 82, 42, 24, 31, 33,  7, 29, 37, 34, 86,  6, 85, 56, 46,
#         5, 17, 60, 76,  9, 38, 69,  4, 32, 93, 68, 96, 87, 36, 16, 35, 45,
#        39, 23, 18, 53, 89, 77,  0, 28, 64, 57, 73, 62, 26, 12, 92, 59, 47,
#        83, 20, 52, 21, 97, 88, 40, 41, 66, 71, 98,  1, 11, 19, 90, 13, 54,
#        84, 43, 48, 95, 67,  3, 10, 51, 72, 27, 74, 44, 79, 25,  8,  2, 22,
#        49, 78, 14, 15, 99, 61, 75, 91, 50, 70, 55, 94, 65, 80, 30])

# %%
X_train = X[random_indices[:70]]
Y_train = Y[random_indices[:70]]
X_train
# Out:
# array([ 0.53946541,  0.856798  ,  1.99919533,  2.06266184, -0.47599889,
#        -1.61839622, -1.17413059, -1.04719755, -2.69732703, -1.30106362,
#        -0.79333148, -0.98373103,  2.31652792, -2.76079354,  2.2530614 ,
#         0.41253237, -0.22213281, -2.82426006, -2.06266184,  0.66639844,
#         1.68186273, -2.57039399, -0.72986496,  1.23759711, -2.88772658,
#        -1.11066407,  2.76079354,  1.17413059,  2.9511931 ,  2.37999443,
#        -0.856798  , -2.12612836, -0.92026451, -0.28559933, -0.66639844,
#        -1.68186273, -1.99919533,  0.22213281,  2.50692747,  1.74532925,
#        -3.14159265, -1.36453014,  0.92026451,  0.47599889,  1.49146318,
#         0.79333148, -1.49146318, -2.37999443,  2.69732703,  0.60293192,
#        -0.1586663 ,  2.12612836, -1.87226229,  0.1586663 , -1.80879577,
#         3.01465962,  2.44346095, -0.60293192, -0.53946541,  1.04719755,
#         1.36453014,  3.07812614, -3.07812614, -2.44346095, -1.93572881,
#         2.57039399, -2.31652792,  0.28559933,  2.18959488, -0.41253237])

# %%
X_val = X[random_indices[70:85]]
Y_val = Y[random_indices[70:85]]
X_val
# Out:
# array([-0.09519978,  2.88772658,  1.11066407, -2.9511931 , -2.50692747,
#         0.09519978,  1.42799666, -1.42799666,  1.5549297 , -0.34906585,
#         1.87226229, -1.5549297 , -2.63386051, -3.01465962, -1.74532925])

# %%
Y_val
# Out:
# array([ 0.50464675,  2.43211862,  1.61203708, -1.10251823, -1.21986432,
#         0.99482732,  2.47335227, -1.45001208,  2.4475526 , -0.11842601,
#         2.25498841, -1.63437404, -1.74433051, -0.78220796, -1.43402902])

# %%
X_test = X[random_indices[85:100]]
Y_test = Y[random_indices[85:100]]
X_test
# Out:
# array([-0.03173326,  1.80879577, -2.2530614 , -2.18959488,  3.14159265,
#         0.72986496,  1.61839622,  2.63386051,  0.03173326,  1.30106362,
#         0.34906585,  2.82426006,  0.98373103,  1.93572881, -1.23759711])

# %%
Y_test
# Out:
# array([ 0.82044155,  2.84721381, -0.92313539, -1.64831212,  1.86523899,
#         1.38353274,  2.11225323,  2.26604838,  0.73566425,  2.36144924,
#         0.91376621,  2.05113791,  1.52711643,  2.64033375, -1.37274499])

# %%
mod_X = np.asarray(X_train.reshape(len(X_train),1))
mod_Y = np.asarray(Y_train.reshape(len(Y_train),1))

# %%
Model = LinearRegression().fit(mod_X,mod_Y)
Pred_mod_Y = Model.predict(mod_X)

# %%
plt.plot(X_train,Y_train,"o",color="black")
plt.plot(mod_X,Pred_mod_Y,color="blue")
plt.title("Fig:2 Data For Linear Regression",color="red")
plt.xlabel("X-trained values",color="red")
plt.ylabel("Y-trained values",color="red")
plt.show()

# %%
M =  np.asarray(X_train.reshape(len(X_train),1))
N =  Model.predict(mod_X)

# %%
plt.plot(M,N,color="blue")
plt.title("Fig:3 Fitted Line For Linear Regression",color="red")
plt.show()

# %%
mn_val_error = Model.predict(X_val.reshape(len(X_val),1))**2
mn_val_error
# Out:
# array([[0.14666208],
#        [7.88149344],
#        [1.85792047],
#        [3.75701699],
#        [2.48761206],
#        [0.28913852],
#        [2.62755727],
#        [0.49041069],
#        [2.97266431],
#        [0.03119815],
#        [3.92856273],
#        [0.64554915],
#        [2.82369038],
#        [3.95964759],
#        [0.91817004]])

# %%
mn_test_error = Model.predict(X_test.reshape(len(X_test),1))**2
mn_test_error
# Out:
# array([[0.18883247],
#        [3.72673952],
#        [1.87931655],
#        [1.74054707],
#        [9.08259654],
#        [1.10997442],
#        [3.15320047],
#        [6.76553851],
#        [0.23632461],
#        [2.30373727],
#        [0.55361175],
#        [7.59452207],
#        [1.58731808],
#        [4.13570769],
#        [0.29761621]])

# %% [markdown]
# ## PART TWO

# %%
df = pd.read_csv('loan.csv')

# %%
print(df.head(10))
# Out:
#    Income  Loan Amount Default
# 0      15            8      No
# 1      30            8      No
# 2       5            9     Yes
# 3      22           10      No
# 4      33           12      No
# 5      18           15      No
# 6      28           20      No
# 7      12           21     Yes
# 8      24           22     Yes
# 9       9           30     Yes

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Income       30 non-null     int64
#  1   Loan Amount  30 non-null     int64
#  2   Default      30 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 848.0+ bytes
# None

# %%
x = df['Default']
y = df['Income']
sb.boxplot(x = x, y = y)
# Out:
# <AxesSubplot:xlabel='Default', ylabel='Income'>

# %%
x = df["Loan Amount"]
y = df["Income"]
hue = df["Default"]
sb.scatterplot(x=x , y=y, hue=hue, markers=["^","o"],s= 150)
# Out:
# <AxesSubplot:xlabel='Loan Amount', ylabel='Income'>

# %%
A= df['Default']

# %%
List =['Income','Loan Amount']
B =df[List]

# %%
x_train,x_test,y_train,y_test = train_test_split(B,A, train_size=0.8,stratify=A, random_state = 1234)
x_train.shape
# Out:
# (24, 2)

# %%
x_test.shape
# Out:
# (6, 2)

# %%
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import classification_report
from sklearn import tree

# %%
Classifier = DecisionTreeClassifier(random_state=100)

# %%
Classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=100)

# %%
predict = Classifier.predict(x_test)

# %%
Accuracy_Score = accuracy_score(predict, y_test)
Accuracy_Score *= 100
print(Accuracy_Score)
# Out:
# 50.0

# %%
plt.figure(figsize=(15,15))
tree.plot_tree(Classifier, feature_names=list(B), class_names=['No','Yes'],filled = True)
plt.show()

# %%
import pydot as pdt

# %%
import graphviz as gp
